# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import gzip
from struct import unpack
from collections import namedtuple, Counter, defaultdict
from pathlib import Path
from urllib.request import urlretrieve
from urllib.parse import urljoin
from datetime import timedelta
from time import time

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %% [markdown]
# ### Plotting Imports

# %%
# %matplotlib inline
from pylab import mpl, plt

# %%
plt.style.use('seaborn')
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'

# %%
import configparser
c = configparser.ConfigParser()
c.read('../pyalgo.cfg')
# Out:
# []

# %%
# !pip install Quandl
# Out:
# Collecting Quandl
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: more-itertools in /home/antash/anaconda3/lib/python3.7/site-packages (from Quandl) (8.2.0)
# Collecting inflection>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: pandas>=0.14 in /home/antash/anaconda3/lib/python3.7/site-packages (from Quandl) (1.3.5)
# Requirement already satisfied: python-dateutil in /home/antash/anaconda3/lib/python3.7/site-packages (from Quandl) (2.8.1)
# Requirement already satisfied: requests>=2.7.0 in /home/antash/anaconda3/lib/python3.7/site-packages (from Quandl) (2.31.0)
# Requirement already satisfied: six in /home/antash/anaconda3/lib/python3.7/site-packages (from Quandl) (1.14.0)
# Requirement already satisfied: numpy>=1.8 in /home/antash/anaconda3/lib/python3.7/site-packages (from Quandl) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /home/antash/anaconda3/lib/python3.7/site-packages (from pandas>=0.14->Quandl) (2023.3.post1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/antash/anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->Quandl) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/antash/anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->Quandl) (2019.11.28)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/antash/anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->Quandl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/antash/anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->Quandl) (2.8)
# Installing collected packages: inflection, Quandl
# Successfully installed Quandl-3.7.0 inflection-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl as q

# %%
q.ApiConfig.api_key = "hgL_AKJMbRpUKV3WRt5N"

# %%
d = q.get('BCHAIN/MKPRU')
d
# Out:
#                Value
# Date
# 2009-01-02      0.00
# 2009-01-03      0.00
# 2009-01-04      0.00
# 2009-01-05      0.00
# 2009-01-06      0.00
# ...              ...
# 2024-01-03  44958.98
# 2024-01-04  42854.95
# 2024-01-05  44190.10
# 2024-01-06  44181.10
# 2024-01-07  43975.63
#
# [5484 rows x 1 columns]

# %%
d['SMA'] = d['Value'].rolling(100).mean()

# %%
d.loc['2023-1-1':].plot(title= 'BTC/USD exchange rate',
                       figsize=(20,20))
